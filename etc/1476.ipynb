# %% [markdown]
# # 1476 날짜계산

# %%
E, S, M = map(int,input().split())
# Out:
#  15 28 19

# %%
year = 1

while (((year-E)%15 == 0) & ((year-S)%28 == 0) & ((year-M)%19 == 0)) != 1:
    year += 1
# Out:
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# 띵요
# ...

# %%
print(year)
# Out:
# 7980
